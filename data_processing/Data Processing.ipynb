# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/daniel/Documents/NTX-Competition-2023/data merging/combined_data_20230622_192229.csv')

# %%
df
# Out:
#       New EMG times  currentData_1  currentData_2  currentData_3  \
# 0         25:17.533           0.00           0.00           0.01
# 1         25:17.942          -0.01           0.00          -0.01
# 2         25:17.958           0.00           0.00           0.00
# 3         25:17.976           0.00          -0.01          -0.01
# 4         25:17.987           0.00          -0.01          -0.01
# ...             ...            ...            ...            ...
# 33640     35:41.968           0.00           0.00           0.01
# 33641     35:41.976           0.00           0.00           0.01
# 33642     35:41.984           0.01           0.00           0.00
# 33643     35:41.992           0.00           0.00           0.00
# 33644     35:42.032           0.00          -0.01          -0.01
#
#        currentData_4  currentData_5  currentData_6  currentData_7  \
# 0               0.00           0.00           0.00           0.01
# ...

# %%
emg_data = df.iloc[:, 1:9].values.T
mediapipe_data = df.iloc[:, 9:].values.T
time_data = df.iloc[:,0].values.T

# %%
# Out:
# array(['25:17.533', '25:17.942', '25:17.958', ..., '35:41.984',
#        '35:41.992', '35:42.032'], dtype=object)
